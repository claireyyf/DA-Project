# %%
import pandas as pd
import numpy as np

# %%
reviews_df = pd.read_csv('googlereviews.csv')
#remove duplex index
reviews_df = reviews_df[reviews_df.columns[1:]]

# %%
#only load Android apps because reviews are all from Play Store
google_df = pd.read_csv('google.csv')
#remove duplex index column
google_df = google_df[google_df.columns[1:]]
google_df.head()
# Out:
#                                                  app  rating  rating_count  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook     4.1           159
# 1                                Coloring book moana     3.9           967
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...     4.7         87510
# 3                              Sketch - Draw & Paint     4.5        215644
# 4              Pixel Draw - Number Art Coloring Book     4.3           967
#
#    size  installs  type  price content   category
# 0  19.0     10000  Free    0.0      4+  Lifestyle
# 1  14.0    500000  Free    0.0      4+  Lifestyle
# 2   8.7   5000000  Free    0.0      4+  Lifestyle
# 3  25.0  50000000  Free    0.0     12+  Lifestyle
# 4   2.8    100000  Free    0.0      4+  Lifestyle

# %%
google_df.groupby('category').size()
# Out:
# category
# Books & Reference     223
# Business              263
# Education             168
# Entertainment        1774
# Finance               302
# Food & Drink           94
# Games                 985
# Health & Fitness      244
# Lifestyle             424
# Medical               290
# Navigation            118
# News                  204
# Photo & Video         453
# Productivity          346
# Shopping              180
# Social Networking     593
# Sports                260
# Travel                187
# Utilities            1016
# Weather                72
# dtype: int64

# %% [markdown]
# <h3><span style='color:orange'>I wonder if there's an easier way to do the lists?</span>

# %%
#Create list of app names for each category

book_ref = list(google_df[google_df['category'] == 'Books & Reference']['app'])
business = list(google_df[google_df['category'] == 'Business']['app'])
edu = list(google_df[google_df['category'] == 'Education']['app'])
entertainment = list(google_df[google_df['category'] == 'Entertainment']['app'])
finance = list(google_df[google_df['category'] == 'Finance']['app'])
food_drink = list(google_df[google_df['category'] == 'Food & Drink']['app'])
games = list(google_df[google_df['category'] == 'Games']['app'])
health_fit = list(google_df[google_df['category'] == 'Health & Fitness']['app'])
lifestyle = list(google_df[google_df['category'] == 'Lifestyle']['app'])
medical = list(google_df[google_df['category'] == 'Medical']['app'])
navigation = list(google_df[google_df['category'] == 'Navigation']['app'])
news = list(google_df[google_df['category'] == 'News']['app'])
photo_vid = list(google_df[google_df['category'] == 'Photo & Video']['app'])
productivity = list(google_df[google_df['category'] == 'Productivity']['app'])
shopping = list(google_df[google_df['category'] == 'Shopping']['app'])
social = list(google_df[google_df['category'] == 'Social Networking']['app'])
sports = list(google_df[google_df['category'] == 'Sports']['app'])
travel = list(google_df[google_df['category'] == 'Travel']['app'])
utilities = list(google_df[google_df['category'] == 'Utilities']['app'])
weather = list(google_df[google_df['category'] == 'Weather']['app'])

# %%
#def cat_reviews():

bkref_rev = list()
business_rev = list()
edu_rev = list()
ent_rev = list()
fin_rev = list()
fodr_rev = list()
healfit_rev = list()
life_rev = list()
med_rev = list()
nav_rev = list()
news_rev = list()
phovid_rev = list()
prod_rev = list()
shop_rev = list()
social_rev = list()
sports_rev = list()
travel_rev = list()
util_rev = list()
weather_rev = list()
not_included = list()

for i in range(len(reviews_df.index)):
    #if i%1000==0:
        #print(i)
    if reviews_df.iloc[i]['app'] in book_ref:
        bkref_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in business:
        business_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in edu:
        edu_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in entertainment:
        ent_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in finance:
        fin_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in food_drink:
        fodr_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in health_fit:
        healfit_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in lifestyle:
        life_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in medical:
        med_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in navigation:
        nav_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in news:
        news_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in photo_vid:
        phovid_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in productivity:
        prod_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in shopping:
        shop_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in social:
        social_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in sports:
        sports_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in travel:
        travel_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in utilities:
        util_rev.append(reviews_df.iloc[i]['review'])

    elif reviews_df.iloc[i]['app'] in weather:
        weather_rev.append(reviews_df.iloc[i]['review'])

    else:
        not_included.append((reviews_df.iloc[i]['app'],reviews_df.iloc[i]['review']))

# return bkref_rev, business_rev, edu_rev, ent_rev, fin_rev, fodr_rev, healfit_rev, life_rev, med_rev, nav_rev, news_rev, phovid_rev, prod_rev, shop_rev, social_rev, sports_rev, travel_rev, util_rev, weather_rev, not_included

# %% [markdown]
# <h2>Sentiment Analysis</h2>

# %% [markdown]
# <h3>Simple sentiment analysis</h3>
# Compute the proportion of positive and negative words in a text

# %%
def get_pos_neg_words():
    def get_words(url):
        import requests
        words = requests.get(url).content.decode('latin-1')
        word_list = words.split('\n')
        index = 0
        while index < len(word_list):
            word = word_list[index]
            if ';' in word or not word:
                word_list.pop(index)##.pop remove item at current index
            else:
                index+=1
        return word_list

    #Get lists of positive and negative words
    p_url = 'http://ptrckprry.com/course/ssd/data/positive-words.txt'
    n_url = 'http://ptrckprry.com/course/ssd/data/negative-words.txt'
    positive_words = get_words(p_url)
    negative_words = get_words(n_url)
    return positive_words,negative_words

# %%
bkref_rev_str = ''.join(bkref_rev)
business_rev_str = ''.join(business_rev)
edu_rev_str = ''.join(edu_rev)
ent_rev_str = ''.join(ent_rev)
fin_rev_str = ''.join(fin_rev)
fodr_rev_str = ''.join(fodr_rev)
healfit_rev_str = ''.join(healfit_rev)
life_rev_str = ''.join(life_rev)
med_rev_str = ''.join(med_rev)
nav_revs_str = ''.join(nav_rev)
news_rev_str = ''.join(news_rev)
phovid_rev_str = ''.join(phovid_rev)
prod_rev_str = ''.join(prod_rev)
shop_rev_str = ''.join(shop_rev)
social_rev_str = ''.join(social_rev)
sports_rev_str = ''.join(sports_rev)
travel_rev_str = ''.join(travel_rev)
util_rev_str = ''.join(util_rev)
weather_rev_str = ''.join(weather_rev)
#not_included = ''.join(bkref_rev)

# %%
def do_pos_neg_sentiment_analysis(text_list,debug=False):
    positive_words,negative_words = get_pos_neg_words()
    from nltk import word_tokenize
    results = list()
    for text in text_list:
        cpos = cneg = 0
        for word in word_tokenize(text[1]):
            if word in positive_words:
                if debug:
                    print("Positive",word)
                cpos+=1
            if word in negative_words:
                if debug:
                    print("Negative",word)
                cneg+=1
        results.append((text[0],cpos/len(word_tokenize(text[1])),cneg/len(word_tokenize(text[1]))))
    return results

do_pos_neg_sentiment_analysis([('bkref_rev',bkref_rev_str),('business_rev', business_rev_str),('edu_rev',edu_rev_str),
                              ("ent_rev",ent_rev_str),("fin_rev",fin_rev_str),("fodr_rev",fodr_rev_str),
                               ('healfit_rev',healfit_rev_str),("life_rev",life_rev_str),
                               ("med_rev",med_rev_str),("nav_revs",nav_revs_str),("news_rev",news_rev_str),
                               ("phovid_rev",phovid_rev_str),("prod_rev",prod_rev_str),
                               ("shop_rev",shop_rev_str),("social_rev",social_rev_str),
                               ("sports_rev",sports_rev_str),("travel_rev",travel_rev_str),
                               ("util_rev",util_rev_str ),("weather_rev",weather_rev_str)
                              ])
# Out:
# [('bkref_rev', 0.06057249957403305, 0.028624978701652752),
#  ('business_rev', 0.06678105696636925, 0.03603294440631435),
#  ('edu_rev', 0.07614757614757615, 0.025139425139425138),
#  ('ent_rev', 0.0670393445421183, 0.0371824414668146),
#  ('fin_rev', 0.05722538393342294, 0.034375268109932224),
#  ('fodr_rev', 0.06838168817292677, 0.029506040930385467),
#  ('healfit_rev', 0.07608888888888889, 0.032276543209876545),
#  ('life_rev', 0.07108613643508331, 0.030454259666771455),
#  ('med_rev', 0.06688327399675088, 0.029345684559814733),
#  ('nav_revs', 0.05542168674698795, 0.024096385542168676),
#  ('news_rev', 0.050730267246737105, 0.04338875077688005),
#  ('phovid_rev', 0.061652876597662665, 0.034802485431892086),
#  ('prod_rev', 0.05829585330895072, 0.03200217466515099),
#  ('shop_rev', 0.05930491531568861, 0.03299321489615165),
#  ('social_rev', 0.05869807504437442, 0.03680669262627791),
#  ('sports_rev', 0.05834909532136612, 0.03765033367831269),
#  ('travel_rev', 0.05947368421052632, 0.03243421052631579),
#  ('util_rev', 0.0660968094622801, 0.0375211211609184),
#  ('weather_rev', 0.06019095060190951, 0.0352843503528435)]

# %% [markdown]
# <h2>Simple sentiment analysis using NRC </h2>
# <li>NRC data codifies words with emotions</li>
# <li>14,182 words are coded into 2 sentiments and 8 emotions</li>

# %%
def get_nrc_data():
    nrc = "/Users/siqi/Desktop/Data_Analytics/lecture/data2/NRC-emotion-lexicon-wordlevel-alphabetized-v0.92.txt"
    count=0
    emotion_dict=dict()
    with open(nrc,'r') as f:
        all_lines = list()
        for line in f:
            if count < 46:
                count+=1
                continue
            line = line.strip().split('\t')
            if int(line[2]) == 1:
                if emotion_dict.get(line[0]):
                    emotion_dict[line[0]].append(line[1])
                else:
                    emotion_dict[line[0]] = [line[1]]
    return emotion_dict

# %%
emotion_dict = get_nrc_data()

# %%
def emotion_analyzer(text,emotion_dict=emotion_dict):
    #Set up the result dictionary
    emotions = {x for y in emotion_dict.values() for x in y}
    emotion_count = dict()
    for emotion in emotions:
        emotion_count[emotion] = 0

    #Analyze the text and normalize by total number of words
    total_words = len(text.split())
    for word in text.split():
        if emotion_dict.get(word):
            for emotion in emotion_dict.get(word):
                emotion_count[emotion] += 1/len(text.split())
    return emotion_count

# %%
def comparative_emotion_analyzer(text_tuples,object_name="Restaurant",print_output=False):
    if print_output:
        print("%-20s %1s\t%1s %1s %1s %1s   %1s %1s %1s %1s"%(object_name,
                                                              "fear","trust","negative","positive",
                                                              "joy","disgust","anticip", "sadness",
                                                              "surprise"))
    import pandas as pd
    df = pd.DataFrame(columns=[object_name,'Fear','Trust','Negative',
                           'Positive','Joy','Disgust','Anticipation',
                           'Sadness','Surprise'],)
    df.set_index(object_name,inplace=True)
    
    output = df    
    for text_tuple in text_tuples:
        text = text_tuple[1] 
        result = emotion_analyzer(text)
        if print_output:
            print("%-20s %1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f\t%1.2f"%(
                text_tuple[1][0:20],result['fear'],result['trust'],
                  result['negative'],result['positive'],result['joy'],result['disgust'],
                  result['anticipation'],result['sadness'],result['surprise']))
        df.loc[text_tuple[0]] = [result['fear'],result['trust'],
                  result['negative'],result['positive'],result['joy'],result['disgust'],
                  result['anticipation'],result['sadness'],result['surprise']]
    return output
#And test it        
comparative_emotion_analyzer([('bkref_rev',bkref_rev_str),('business_rev', business_rev_str),('edu_rev',edu_rev_str),
                              ("ent_rev",ent_rev_str),("fin_rev",fin_rev_str),("fodr_rev",fodr_rev_str),
                               ('healfit_rev',healfit_rev_str),("life_rev",life_rev_str),
                               ("med_rev",med_rev_str),("nav_revs",nav_revs_str),("news_rev",news_rev_str),
                               ("phovid_rev",phovid_rev_str),("prod_rev",prod_rev_str),
                               ("shop_rev",shop_rev_str),("social_rev",social_rev_str),
                               ("sports_rev",sports_rev_str),("travel_rev",travel_rev_str),
                               ("util_rev",util_rev_str ),("weather_rev",weather_rev_str)
                              ])
# Out:
#                   Fear     Trust  Negative  Positive       Joy   Disgust  \
# Restaurant
# bkref_rev     0.012273  0.027693  0.022343  0.061995  0.022448  0.006818
# business_rev  0.012509  0.039682  0.027173  0.057410  0.024190  0.005716
# edu_rev       0.011256  0.040797  0.023939  0.085927  0.033557  0.005813
# ent_rev       0.018328  0.034333  0.027363  0.061610  0.036054  0.009087
# fin_rev       0.012690  0.052234  0.025929  0.065336  0.029221  0.005762
# fodr_rev      0.009855  0.034694  0.025744  0.069590  0.032683  0.005129
# healfit_rev   0.014559  0.042401  0.028780  0.072481  0.039056  0.009265
# life_rev      0.012629  0.034409  0.022685  0.060192  0.034171  0.006958
# med_rev       0.015024  0.038935  0.024123  0.065640  0.025393  0.006644
# nav_revs      0.013067  0.027358  0.019192  0.042466  0.013475  0.003267
# news_rev      0.018654  0.031864  0.034231  0.049240  0.019317  0.010179
# phovid_rev    0.014780  0.030606  0.028284  0.054633  0.029561  0.007622
# prod_rev      0.013602  0.030696  0.026688  0.052071  0.022650  0.006801
# shop_rev      0.015478  0.037661  0.025442  0.068931  0.038100  0.007457
# social_rev    0.013498  0.033604  0.029176  0.050946  0.023967  0.008904
# sports_rev    0.017458  0.029780  0.028882  0.051388  0.025117  0.010055
# travel_rev    0.012104  0.038789  0.027963  0.057604  0.027404  0.006551
# util_rev      0.018241  0.029313  0.030826  0.051971  0.023807  0.008440
# weather_rev   0.015306  0.036735  0.023469  0.045918  0.019898  0.003571
#
#               Anticipation   Sadness  Surprise
# Restaurant
# bkref_rev         0.023917  0.012588  0.010385
# business_rev      0.028829  0.014580  0.009610
# edu_rev           0.029594  0.011520  0.012366
# ent_rev           0.040563  0.014663  0.013819
# fin_rev           0.037933  0.013822  0.014679
# fodr_rev          0.034091  0.013878  0.009453
# healfit_rev       0.037925  0.019323  0.013740
# life_rev          0.029881  0.012057  0.011200
# med_rev           0.029836  0.012908  0.010538
# nav_revs          0.033891  0.011025  0.011842
# news_rev          0.029307  0.018039  0.010748
# phovid_rev        0.029986  0.017218  0.012730
# prod_rev          0.026293  0.014209  0.010293
# shop_rev          0.044366  0.011530  0.020679
# social_rev        0.031074  0.013748  0.011534
# sports_rev        0.038894  0.014805  0.014933
# travel_rev        0.031319  0.013942  0.014900
# util_rev          0.027407  0.015186  0.013462
# weather_rev       0.028571  0.014796  0.010714

# %% [markdown]
# # Apple Reviews

# %%
apple_df = pd.read_csv('apple_reviews.csv')

#select col I want
apple_df=apple_df[['i','review...Review...']]

#rename col names
apple_df.columns = ['Appid', 'reviews']

# %%
apple_df.head()
# Out:
#        Appid                                            reviews
# 0  281796108  The Mac app is great. I have little to no prob...
# 1  281796108  The app has a lot of cool features\nBut it cra...
# 2  281796108  Using this like a good unauthorized user would...
# 3  281796108  Too many Evernote haters out there, but no ser...
# 4  281796108  I loved Evernote but I feel like they keep mak...

# %%
apple_data_df = pd.read_csv('apple.csv')

# %%
apple_data_df.head()
# Out:
#    Unnamed: 0         id                                                app  \
# 0           0  281656475                                    PAC-MAN Premium
# 1           1  281796108                          Evernote - stay organized
# 2           2  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           3  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           4  282935706                                              Bible
#
#       size  price  rating_count  rating_count_ver  rating  rating_ver content  \
# 0  100.788   3.99         21292                26     4.0         4.5      4+
# 1  158.579   0.00        161065                26     4.0         3.5      4+
# 2  100.524   0.00        188583              2822     3.5         4.5      4+
# 3  128.512   0.00        262241               649     4.0         4.5     12+
# 4   92.774   0.00        985920              5320     4.5         5.0      4+
#
#             category
# 0              Games
# 1       Productivity
# 2            Weather
# 3           Shopping
# 4  Books & Reference

# %%
apple_data_df["category"].unique()
# Out:
# array(['Games', 'Productivity', 'Weather', 'Shopping',
#        'Books & Reference', 'Finance', 'Entertainment', 'Utilities',
#        'Travel', 'Social Networking', 'Sports', 'Business',
#        'Health & Fitness', 'Photo & Video', 'Navigation', 'Education',
#        'Lifestyle', 'Food & Drink', 'News', 'Medical'], dtype=object)

# %%
apple_data_df.groupby("category").size()
# Out:
# category
# Books & Reference     176
# Business               57
# Education             453
# Entertainment         675
# Finance               104
# Food & Drink           63
# Games                3861
# Health & Fitness      180
# Lifestyle             144
# Medical                23
# Navigation             46
# News                   75
# Photo & Video         350
# Productivity          178
# Shopping              122
# Social Networking     167
# Sports                114
# Travel                 81
# Utilities             248
# Weather                72
# dtype: int64

# %%
#Create list of app names for each category

apple_book_ref = list(apple_data_df[apple_data_df['category'] == 'Books & Reference']['id'])
apple_business = list(apple_data_df[apple_data_df['category'] == 'Business']['id'])
apple_edu = list(apple_data_df[apple_data_df['category'] == 'Education']['id'])
apple_entertainment = list(apple_data_df[apple_data_df['category'] == 'Entertainment']['id'])
apple_finance = list(apple_data_df[apple_data_df['category'] == 'Finance']['id'])
apple_food_drink = list(apple_data_df[apple_data_df['category'] == 'Food & Drink']['id'])
apple_games = list(apple_data_df[apple_data_df['category'] == 'Games']['id'])
apple_health_fit = list(apple_data_df[apple_data_df['category'] == 'Health & Fitness']['id'])
apple_lifestyle = list(apple_data_df[apple_data_df['category'] == 'Lifestyle']['id'])
apple_medical = list(apple_data_df[apple_data_df['category'] == 'Medical']['id'])
apple_navigation = list(apple_data_df[apple_data_df['category'] == 'Navigation']['id'])
apple_news = list(apple_data_df[apple_data_df['category'] == 'News']['id'])
apple_photo_vid = list(apple_data_df[apple_data_df['category'] == 'Photo & Video']['id'])
apple_productivity = list(apple_data_df[apple_data_df['category'] == 'Productivity']['id'])
apple_shopping = list(apple_data_df[apple_data_df['category'] == 'Shopping']['id'])
apple_social = list(apple_data_df[apple_data_df['category'] == 'Social Networking']['id'])
apple_sports = list(apple_data_df[apple_data_df['category'] == 'Sports']['id'])
apple_travel = list(apple_data_df[apple_data_df['category'] == 'Travel']['id'])
apple_utilities = list(apple_data_df[apple_data_df['category'] == 'Utilities']['id'])
apple_weather = list(apple_data_df[apple_data_df['category'] == 'Weather']['id'])

# %%
apple_food_drink
# Out:
# [296581815,
#  299515267,
#  320650307,
#  324887734,
#  331004675,
#  331177714,
#  340368403,
#  392408028,
#  406732590,
#  409157308,
#  413618155,
#  419724490,
#  436491861,
#  440677948,
#  453809428,
#  466252999,
#  478618165,
#  488818252,
#  502803489,
#  507051584,
#  507161324,
#  512393983,
#  519131315,
#  521577043,
#  551682016,
#  587248280,
#  588797948,
#  589653414,
#  604687408,
#  668515245,
#  672175251,
#  691617940,
#  719972451,
#  737310995,
#  753237901,
#  813952961,
#  867827909,
#  895506023,
#  903911740,
#  911686788,
#  922103212,
#  977041956,
#  977965019,
#  980368562,
#  1001501844,
#  1022844131,
#  1027284532,
#  1035361376,
#  1056813463,
#  1058959277,
#  1059134258,
#  1060973985,
#  1078665338,
#  1079607960,
#  1085497387,
#  1091627644,
#  1101445404,
#  1104112723,
#  1110429957,
#  1111504254,
#  1131203082,
#  1141643627,
#  1177907423]

# %%
apple_data_df[apple_data_df['id']==296581815]
# Out:
#     Unnamed: 0         id                                  app    size  price  \
# 56          56  296581815  OpenTable - Restaurant Reservations  93.421    0.0
#
#     rating_count  rating_count_ver  rating  rating_ver content      category
# 56        113936               150     4.5         5.0      4+  Food & Drink

# %%
apple_bkref_rev = list()
apple_business_rev = list()
apple_edu_rev = list()
apple_ent_rev = list()
apple_fin_rev = list()
apple_fodr_rev = list()
apple_healfit_rev = list()
apple_life_rev = list()
apple_med_rev = list()
apple_nav_rev = list()
apple_news_rev = list()
apple_phovid_rev = list()
apple_prod_rev = list()
apple_shop_rev = list()
apple_social_rev = list()
apple_sports_rev = list()
apple_travel_rev = list()
apple_util_rev = list()
apple_weather_rev = list()
apple_not_included = list()

for i in range(len(apple_df.index)):
    #if i%1000==0:
        #print(i)
    if apple_df.iloc[i]['Appid'] in apple_book_ref:
        apple_bkref_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_business:
        apple_business_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_edu:
        apple_edu_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_entertainment:
        apple_ent_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_finance:
        apple_fin_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_food_drink:
        apple_fodr_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_health_fit:
        apple_healfit_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_lifestyle:
        apple_life_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_medical:
        apple_med_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_navigation:
        apple_nav_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_news:
        apple_news_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_photo_vid:
        apple_phovid_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_productivity:
        apple_prod_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_shopping:
        apple_shop_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_social:
        apple_social_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_sports:
        apple_sports_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_travel:
        apple_travel_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_utilities:
        apple_util_rev.append(apple_df.iloc[i]['reviews'])

    elif apple_df.iloc[i]['Appid'] in apple_weather:
        apple_weather_rev.append(apple_df.iloc[i]['reviews'])

    else:
        apple_not_included.append((apple_df.iloc[i]['Appid'],apple_df.iloc[i]['reviews']))

# %%
apple_bkref_rev
# Out:
# ['Amo a mi padre Dios todo poderoso y mi guía de Luz mi señor Cristo  Jesús',
#  'The Bible App gives us God’s Word, with us always.  I love that the convenience & immediate access to Scriptures, and daily Bible Plans are given to us.  Thank you Life.Church leaders & Bobby’s staff for creating the Bible App, and the Bible Lens.',
#  'This Bible app makes it so easy to read my Bible daily, especially as I travel. The plans are exceptional with so many choices available. Having this app is truly a daily blessing.',
#  "Ok so idk but I use to be able to go to a book or chapter and be able to find a verse as well on the top where I can choose the book I wanted to look into the pick verse and it would take me and their but now I don't have that option why?",
#  'Yes very powerful',
#  'I love this app and have used it for years. So easy to use and the devotions are amazing. I recommend this app for everyone. ❤️',
#  'I’ve never had an issue with it. I’m addicted to it, Amen!  Everyday, I read the Verse Of The Day; plus they have have videos you can watch, plans you can do, bible images you can view (or create!), there’s a cool Bible Lense you should check out, where you can use your own picture to create your own bible verses with to save or share on social media, and so much more!  You don’t even have to worry about which version of the Bible you’re used to reading from because they have dozens to choose from and compare!  There’s even a children’s version too!  Hands down, the best app you’ll ever download. It may just save you life!  Thank you Bible App!  Glory be to God in the Highest and to our Lord Jesus Christ!  Amen 🙏🏻 💜',
#  'Es una bendición puedo leer y saber más donde esté , de nuestro Dios y su palabra me encanta !! Me conforta me alimenta me guía .',
#  'Thank you to all the people behind the Bible app working to make It possible. The app is a blessing, you guys are a blessing.',
#  'It’s great. Love everything about this app. I recommend it to anyone who needs to be connected with God everyday. Also like the fact that you can receive verse of the day offline❤️',
#  '“This is very helpful and convenient for sermons. Also Bible study.” Wow took the words right out of my mouth',
#  'Hasn’t been working for me, just updated the new version so we’ll see. Only thing I don’t like is the tracker, it’s killing me spiritually.',
#  'The best App ever!! Thank you for listening to everyone and letting us change the streak free week thing to be able to move it to the bottom!! You guys are the greatest!! Keep up the awesome and Godly work!! God bless y’all!! Thank you!!',
#  'I love this app! There are so many uses. From bible studies, to making beautiful pictures filled with the word to just simply being a bible! It’s even more amazing that it alerts me to do my quiet time reading, prayer and meditation on the word! Just amazing!',
#  'I enjoy how accessible it is.',
#  'I’m so bless with this app, I enjoy everyday reading the word of God',
#  'I truly love this app. On stressful work days, while I have to drive to different locations, I plug it into my radio and listen. It brings peace to my day and I am reminded that "all things are possible..." Also, really nice to fall asleep to.\nThe only thing missing is a downloadable audio Catholic version. Please do that soon!!!\nYou might bump this to 5 stars!',
#  'This app is great!',
#  'This bible app is awesome. I love all the translations and options to save and highlight scripture. Really great tool for studying and learning scripture on the go!',
#  'The Bible app is a very helpful information that keeps individual who wants to know more about God. It broadens your knowledge and makes me anxious to know more.',
#  'I have deeply struggled with my life after my divorce for the past nine years getting the king James version I have more focus on God and the people around me to be a better man I feel guilty if I miss a day my longest streak was 86 days I ended up missing one day but was not deterred and continued reading the word of God I am so grateful for what God and Jesus have done for me and I love the fact that I’m reminded of it every day that God is with me through the word of this book at the tip of my fingers I think God and Jesus Christ for what they’ve done for me on a daily basis to continue to remind myself no matter how hard life can be that Jesus is there with me and my father God to pick me up to brush me off and help me move forward through my struggles I hope that anybody that decides to download this app can get through their worries their troubles and their hardships in life as I know they can read in the word of God on a daily basis\nMy name is Chad Binsfield I live in Duluth Minnesota thank you for making this available',
#  "This app helps me be closer to our Lord when I don't have a bible. This app is perfect for on the go also.",
#  'The Bible app allows individuals to grow and learn more about the power of Christ. This app is very easy to use and understand.',
#  'I enjoy being able to have different translations just a few taps away.   I have also enjoyed the different study plans.',
#  'I like this because it has a lot of versions and you can change it to Spanish or English which ever language you want the Bible to be. This is also nice because you can highlight and make notes through the passages. And they also have like daily reading bible stuff and also gives you notifications of bibles verses.',
#  'I love this Bible app has a lot of good stuff what I really would love to see youversion add is dramatized Bible I have the tecarta Bible app and they have the Bible being dramatized I really pray that Youversion can add this it makes the Bible more realistic it’s like you’re in the actual Bible times please add this feature',
#  'It’s a very good bible when ever it comes to church and classes.\nI like how it has different chapters and catigorys.',
#  'Access to God’s word throughout the day is a necessary tool in the age of technology or demanding schedules.\n\nServe the Lord at all times and be studious, knowing that there is a time and season for all things.\n\nWe must continue to sew, knowing that in due time we shall reap.',
#  'This app is one of the best Bible apps it is truly AMAZING! Would definitely recommend',
#  'Pretty noice',
#  "Thank you so much for creating this app! I love it and it encourages me every day to stay in God's Word. Your app inspired me to create an Instagram account 4 years ago to try to reach as many people as possible for Jesus! ❤️",
#  'This app is truly incredible. We just set our church up with the events feature and are very excited!',
#  'I love the Holy Bible app because I get to learn about God and also get great plans to know God better. I get to send my friends encouraging verse and they help with hard times too. This app is a big impact on my life and friends.',
#  'The best app.',
#  'It not that easy to get to the Bible',
#  'I like this app I really do,and it’s helpful when I can’t find my own bible but..........\nQUIT SENDING ME YOUR STUPID EMAILS BECAUSE I CANT DO ANY OF THAT STUFF!\nI’m not a facebooker for good reason and i don’t intend to start now so I can just be apart of that other stuff.\nYou say”Gods word is the most important thing in the universe,” and I couldn’t agree more, BUT YA DONT NEED TO SEND DARN EMAILS FOR EVERY LITTLE THING YOU DO! \nThat’s why I only give three stars. I wish I could give more, but I ain’t doing that until you stop sending emails so.......\n\nPlease respond as soon as you can because I want to give five stars.all I want to know is how to get rid of your of stupid emails.',
#  'It’s really amazing to get verse everyday,it’s  help me,Thanks a lot 👼😍',
#  'Our walk to follow Christ can be very difficult. It’s such a pleasure to have Bible App assistance in that Walk  ! \nThank You !!! Teddy',
#  'Hello! I’ve been using the Bible App for several years, and it is a fantastic way to study!\nI have a suggestion; it would be cool to be able to fill in the days and reading plans after being away from the app but still having read somehow else. For example, if you could fill in the days you read so as to not have an inaccurate number of days that you read, and if you could fill in passages that you read to make up for the plans that you missed without having to go through all of them, that would be very efficient and accurate.\n\nThank you for the work you do!',
#  'At first I found it a little confusing, how to do what and what does this mean, but I think it’s just because I’m not used to it. I love how this app offers you the choice to surround yourself with friends! I ding that very encouraging and a helpful motivation to fit a Devotion and a conversation in my busy schedule. In many ways I think this app is a wonderful tool and a great outreach to all believers everywhere. I think every Christian needs to find a rhythm, a plan, an app that works for them. And not everyone will be the same, but I know for me, this is just the app I needed:)',
#  'This Bible app has been the perfect tool for my spiritual growth.\n\nWe all need help with being consistent in our walk, and the daily reminders and plans that are available here are truly a blessing and an encouragement at the same time. I am very thankful for this app and program.',
#  'The Bible’s daily scripture help us through the day.  Graces from Jesus is wonderful while living our truest path, our mission in a world full of chaos.  Praise Jesus, thanks be to god!!  It’s a wonderful App!',
#  'So thankful to God and the developers for this app!',
#  'May God bless the designers of this great Bible app. Amen!',
#  'This application is amazing and giving us our daily bread the word daily! I love this application!',
#  'The Bible app is one if the best tools that the internet could offer. Thanks I love to read a daily devotion💞🙏🏽👠',
#  'I love this app so much . I love getting the daily’s verses it helps me stay on the right path by reading a verse very morning. Also having the Bible at your fingertips no matter where you are is nice too. And the way it’s categorized it’s easy to find verses in Scripture even if you are new to the Bible.',
#  'Through the love of God to send his one and only son to make away for all of us to enter the kingdom of heaven. The Lord full of love showing mercy, in doing this . Dying on the cross of brutal horrific crucifixion rose on the third day cleansed the world through his blood that he shed for all of us. God bless you Jesus father son Holy Spirit for blessing us. 🙏',
#  'A blessing daily Scripture has been to me!',
#  'The reason why I bought this app was that it allows for continuous playback of multiple suras (choosing different reciters), which as you can imagine can take hours : meaning that at some point the phone’s screen will be locked. This feature doesn’t work when the iphone is locked. I am now browsing remorsefully to YouTube..',
#  'Since iOS updated to 12, while dragging or scrolling down or up (to jump between Ayats) it get freezes. Hope this great app will rectify the issue. Thank you.',
#  'IQuran Pro and the upgrade in IQuran is the same thing. I was charged 6.51 for the same app. That’s a lot of money. Especially because the app didn’t even have the reciter I wanted. Apple won’t refund me and I don’t understand why. If I could rate a 0 I would. I want my money back.',
#  'Can you change the tapping eye icon toggle in the search tab to another icon please after search it appear to mark using one eye visible result in reading',
#  'I love and use this app daily. However, switching from Android to iPhone I realized full English transliteration is not shown under the Arabic writing. This helps guide me to learn better as I do not speak nor read Arabic fluently. If this can be fixed on iPhone’s next update it would be greatly appreciated. Thank you for the wonderful App and I will continue to use it daily even if I have to use it on an old Android phone. The Surah I specifically have issues showing full transliteration text is Surah Waqia (56) where transliteration surpasses one line of text. I also realize the new update has listed this as fixed but my app is up to date and the issue is still occurring.',
#  'I love this app, my fav Quran app so far. I would like to know if there is any possibility in adding another translation. How can I contribute?',
#  'Salaam.  Sorry, but this app is not as good as the iQuran HD. Please consider revising.',
#  'Would give it 5 stars if they had audio controls for each ayat so i can drag back and forth instead of waiting for ayat to end and starting over.',
#  'Thank you',
#  'Alhamdulillah this is very a good app and I use it everyday . Only issue that i have is the bookmark option for reading ,memorizing and interesting they are all same color so there’s no way to differentiate . I think different color for each bookmark option will make the use of it much easier and useful. Jazakallah khayer.',
#  'I have had this app for many years and I absolutely love it! Sometime back there was a short period of time that this app didn’t work on an iOS update. During that time I tried many other Quran apps but struggled to find anything as good or even close! Thankfully the developer fixed the app and I was really happy!\n\nThe best feature of this app is that it includes the English translation by Mohammad Asad. After going through many other translations, I think Asad captures the essence of Allah’s message in the most eloquent manner.\n\nI bookmark and make notes on many ayahs during my daily reading. I only wish and request the developer to make some way for exporting these out. Some suggestions in that regard:\n\n1. E-mail a text file that contains all bookmarks and notes, along with surah and ayah numbers.\n\n2. Save text file to cloud using OneDrive or Google Drive \n\nThank you and God bless!',
#  'App is great but be careful, translieration is incomplete of every aeyah in whole Quran. If you rely on transliteration then it is a disaster. Donot use translietration. Developrs should have fixed it but have not since this App was released.',
#  'Tank you❤️❤️❤️❤️❤️',
#  'Asalamo alikoom ,Plz add Persian language in settings and in more must be Persian also add tafsir from Hal sunat wa l jamahat .\nAlso make the fonts size bigger add tajweed in Persian like ghuna,idgham and thank you very much for making this app for Muslims, may allah bless you all.',
#  'This app has made reading, reciting, listening to, understanding (and trying to memorize) the Quran so easy. There are several reciters to choose from, and several translations in multiple languages by diffferent authors, ... so I chose one in English that was an easy read for me. You can bookmark separately for reading, discussion or memorizing, and can even write notes. You can pause the app and resume, replay just one ayah or a group. JazaakAllah khair for the apps creators.',
#  'Wonderful app, but could you address the transliteration getting cut off. The height of the cell isn’t growing tall enough to show the entire transliteration.',
#  'Love this app! A must have if you are memorizing Quran. Love the gapless playback! \n\nI thing that needs to be fixed: when you want to play the next 2 ayat or next 5 ayat ... they are missing the number 4. Play the next 4 ayat. Can you please fix this! \n\nJazakallah khair! May this be a part of your legacy inshallah!',
#  'Can you pls add one more voice of abubkr alshatry taraweh voice',
#  'Please support iPhone X landscape because not shows some parts of Ayah',
#  'Salamu Aleykum, thank you for fixing errors.',
#  'I am really disappointed with this app. First of all it says it free but it is not. I paid $2.99 for this app.\nSecond, you can’t upload any sourah to enjoy the beautiful recitation of the holy Quran.\nIf the app developers can’t do anything to fix any issues that come up with the app why having it out there.\nIt is really sad to have such a thing out there. I really wants my money back. Shame on you. I will NOT recommend it to anyone.',
#  'Best Quran app! But download stopped working!!!! Need to update for ipads',
#  'Not working',
#  'please update for ipad version also,Unable to downlad Audio iphone, please update',
#  'It’s very helpful app among many Quran app in the store but there is download issue. Kindly rectify the issue.',
#  'I worked and downloaded on my old iPhone 6\nThen when I switched to iPhone X the in app downloading of audio surahs recitation is not going. Just says connecting and that’s it \nPlease please fix \nAlina',
#  'I have not anything in my qoran page it is empty , no any words in spure',
#  'Yes it is only available for the iPhone and could work on iPads but the app is not optimized for the iPad software so it is really uncomfortable to zoom the app.',
#  'it is just need in next update to have reminders inside the app to complete the quran by reading and listening \nThanks',
#  'Very good app. Just one issue - in transliteration mode, last line of Ayah is not displayed.',
#  'Everything is good so far but when I want to stop the reciting in Notification Center it’s not working like before.\nPlease do something about it waiting for the fix \nRegards \nPeace',
#  'Loved this app before the upgrade. I need the transliteration to help me read the arabic part and none of the ayats are complete. This use to be my favorite app to help me read Quran and now it’s just money wasted because I can’t use it for helping me. Please try to fix the transliteration correctly.',
#  'Really well thought and easy to use design. Thanks a lot developer .\n\n I would love to contribute to your efforts if there is anyway.',
#  'الحمد لله \nFinally got the long awaited update, but developers should have a way for us to contact them for additional feedback to better the app. So far so good .. interface has been the same and no glitches during play. One way to improve is to have an interval option for those of us who like to hear the ayat and then recite ourselves .. then I would change it to 5 stars rating. But seeing as how the developers took their time to finally issue the long overdue update (which they only did after the app crashed with the iOS update) I doubt we’ll be seeing any improvements any time soon.',
#  'This is the best Quran app with the proper Arabic font being used. A lot of other apps have problem with the Arabic font.\nAlso has Tajweed.\n\nBut could you please add the Dhivehi (Maldivian) translation!?\n\nSalaam',
#  'Since iOS 11. We are not able to use the iQuran HD app. Please update or apply the fixes. JAK. We all love this app.',
#  'Great app masha’Allah but it’s missing the last word of the transliteration of each ayah',
#  'At one point there was a concern that this app may no longer be supported and I tried looking for apps but nothing comes close to offer; translation transliteration and colored segments allowing you to identify areas needing emphasis on  pronunciation - ability to share verses make notes is amazing',
#  'Tried to use the app but has frozen ... needs an update!',
#  "Change the update there's no any word on the new update",
#  'Asa, I’ve bern using this app for years and it is hands down the best quran app for ios. With this long awaited updated however came a small issue, the text for transliteration is sometimes not fully displayed unless you change to horizontal/vertical view depending on the verse. This was seen for iPhone X. Surah al-burooj is an example of what I am talking about.',
#  'Where is the translation’s option?',
#  'Salamu alaikum.\n\nEach sura is not complete, are you aware of this?',
#  'I was fully satisfied with earlier versions of this App. \nRecently, I downloaded the latest version. I noticed that last portions of the verses get curtailed when I turn my iPhone X in landscape mode. Please attend to this shortcoming ASAP. \nOtherwise, undoubtably this is the best Quran App among 6-7 I have tried.',
#  'iQuran my all time fav quran apps but sadly its been years since 2013 last update.. please update this great apps\n\n*syukur alhamdulillah for updating this great app.. may Allah give u a great success aamiin.. hopefully u continuously updating this app.. next update iPray.. Thank you soo much..',
#  'I upgraded and it is a nightmare. No verse can be seen-empty. All my bookmarks and notes are there yet it is useless since the verse is not there.\nI deleted the app and re-install. Now all fresh even my bookmarks and notes are gone. And the verse is still not there. Please help me.',
#  'Loving the new update. One of the best app. I use it regularly. Plz add the feature that audio recitation continues to next surah automatically.',
#  'So happy that the developers revamped the application for the new iOS compatability. IQuran is my favorite application for Quran memorization and recitation. Thank you again and God bless you.',
#  'Why, in the new version, we can’t access to  Documents via iTunes to backup the database?',
#  "Daijirin dictionary is exquisite. It's also handy for just browsing around to find new words",
#  '界面设计很棒\n出门不用带着电子词典了',
#  'If you are able to handle Japanese-to-Japanese dictionaries, than this is the best one you can find in the entire App Store. The UI is very well-designed and helps a lot in discovering new words/phrases.',
#  "This is the slickest dictionary app I've encountered in general and the most effective use of 3D Touch that I've seen. This has the Super Daijirin dictionary, which is a great dictionary for Japanese->Japanese. Obviously you need to be able to read Japanese already for this to be useful to you since all the definitions are in Japanese. If you are an intermediate learner though it's a good resource.",
#  'Daijirin is one of the best Japanese-language dictionaries there is, and this app is beautifully designed and very dependable. Highly recommended to native speakers, and to students of Japanese at the intermediate level and beyond.  (I know that several reviewers have opined that the app is only suitable for advanced students, but I would argue that learning to use a kokugo jiten is an indispensable step in moving beyond the early intermediate level; of course it is challenging at first, but the benefits are well worth the effort.  Besides, if you weren’t up for an intellectual challenge, then you wouldn’t be studying Japanese!)',
#  "This is one of the few Japanese dictionary apps that looks like anyone actually cared about its development, and it's definitely the best one available.",
#  'Works so nicely. Great user interface.',
#  'This dictionary has been extremely useful to me. It would be even better if there is a feature that allows user to synchronize bookmarks on different devices.',
#  'Great！',
#  '"search"や"bookmark"などがイングリッシュになってしまっています。多分iPhoneを中国語に設定しててこのアプリは中国語版がないからかな。残念です。設定で管理できて日本語にでもすることができたらいいのにな。\n\n「大辞泉」と比較しますと、大辞林は、類語は、別のアプリとして買わないといけないというのが大辞泉に負けるところなんです(大辞泉の類語の機能がすこくいいですよ)。\n\nとは言え、この大辞林は渋いです。使えば使うほど感動します。美しくて、内容も豊富で、参考になるだけじゃなくて、ずっと遊ぶことができます。その値段でこんなに良いものでないといけないのですが。大辞泉も持っているけど、選ぶなら大辞林のほうが美的感覚に優れて勝つでしょう。',
#  "A decent Japanese encyclopedia, with slighter fewer features than the 大辞泉 by 小学館, which seems to be its main competitor on iPad. Both let you search by handwriting, which is nice. The encyclopedias you'd get on a good Japanese electronic dictionary, like the 広辞苑 or the スーパー大辞林 are still better, though, with more entires and more comprehensive information in each entry.",
#  '"the importance of people who could stand at the intersection of humanities and sciences" For 大辞林，you are my favorite!!',
#  "I haven't seen any J-E dictionaries with pitch accent reference, which this has. So if you're serious about japanese then it's worth it.  Plus, once you master the language this will \nprobably be your go to J-App.",
#  'Hi,\n\nThis is a awesome application for practicing reading.\n\nHowever, even with the max size of the FONT, it is still small. Also, when you pinch to increase the font, it doesnt redraw the characters, so you have to read up and down and this makes me dizzy. \n\nThanks again for your help, but please fix the font',
#  'This is the best app to have',
#  "Sanseidō's answer to Iwanami's 広辞苑 Kōjien, Daijirin is a Japanese dictionary/encyclopedia of the highest caliber. Combine that with a sleek, elegant UI and handwriting recognition, and you have the most useful and well-made app I have ever seen on the iPhone.",
#  'このアプリのUIに勝る辞書は無いでしょう。',
#  "Navigation is absolutely brilliant with the index.  Double tap returns you to prior place or you can use back button on top. Most of it is beyond my comprehension of Japanese but my wife (Japanese) loves it.  However, I still like using it as everything is hyperlinked and I can understand the gist of it.  I will mention one thing I would like changed.  Zoom is very pretty you can make the letters gigantic and they stay clear just like a PDF would look zoomed in 400%.  However, the zoom is useless pretty much as the text doesn't wrap at the bottom and that's a ton of up / down scrolling so as long as you don't zoom it's hunky dory. In the settings you can change text size small, medium or large but wish the large text could go like 2 sizes larger.  Half the data ~80MB consists of 2,700 images and the and the other ~60MB is text which is just an insane amount of information at your fingertips.",
#  '使いやすいです！',
#  "Very creative and easy-to-use interface.  I use it all the time.  As another reviewer has said it is probably useful for advanced and native speakers of Japanese, but I'm so glad they released this in U.S. App Store.",
#  'Only for advanced student and native speakers. Regardless, anyone would be impressed with the interface. YouTube it and see for yourself.  Man, it would be amazing if someone came out with a Japanese-English version of this.',
#  'An actual 国語辞典 for my iPhone! Dictionary is standard, interface is fabulous. This will be great for its target audience: native speakers and high level students. Any attempt to criticize this program will undoubtedly come from people who have no business using it.',
#  'I love my Kindle and convenience of ebooks.  I only gave three stars because I believe ebooks are overpriced.  Ebooks are often times more expensive than hardbacks and paperbacks.',
#  'Loooove Kindle. Read all the time.',
#  'Ryker hit another home run! He keeps you on the edge of your seat. You know, appearance sometimes deceiving, the pilot has a plan long in the making, a purpose, and an endgame. It is just that others are not ready to hear it yet. At the right time, with a lot of discipline and even more luck, his teammates will find out. When they do, they will not like it, but they will buy in!\nGet it - you will be glad to become a Ryker’s Raider!',
#  'Very exciting book. I truly had a difficult time putting it down. I was wondering right up to the conclusion how it was going to end.',
#  'This is a great series',
#  'Likeable characters; enjoyable storyline. Leaves several encounters to the imagination, but that makes the romance and violence PG.',
#  'Just read The Fourth Monkey by J. D. Parker and it was a serious, pulsating thriller. I could not put it down. Be prepared for a horrifying, gruesome story that has unexpected twists. The author cleverly weaved the story by rotating the killer’s narrative (through his diary entries),  while developing the other chapters through the perspectives of the detectives chasing this elusive killer.',
#  'This book was a very good book to read for me. It was my level book and it is a bluestem for our school. I really enjoyed reading it and I definitely recommend it.',
#  'What a beautifully illustrated book. A very simple message of what it is to be a friend.',
#  'Portable library at my fingertips. The ability to read a book simultaneously on different devices and whisper-sync with Audible are great features that make reading easier and more enjoyable. Fantastic when traveling.',
#  'Happened in a recent update, most likely due to the addition of Audible functionality.\n\nThis is absolutely unacceptable.',
#  'Just wow!',
#  'I love to read & have lots of books but never seemed to read them.  With a book on my phone or pad, I can read in the middle of the night without waking my husband if I can’t sleep.  I can read anywhere & everywhere with an endless supply of books!\nIt’s a whole new world for me & since I have arthritis & sometimes I just need to rest my hands & arms, this is a life saver!  👍🏻 Thank you ☺️',
#  'Really great read. So glad I stumbled upon this. Some of the language of the time can be a bit of shock to a modern reader but take it for what it was in 1973. Up there with Chandler. Can’t wait to read the next one.',
#  'Overall a simple experience. I appreciate that I can use different fonts in this app allowing me to improve my experience.',
#  'Like finding a special place to hideout, reflect and explore, my kindle takes me away to faraway places, with friends in series I don’t have to let go of. I soak in the stories which always change me, and I find myself having to share. Who can keep this gift all to ones self!',
#  'It is awesome',
#  'Because I love books. And Kindle makes it easy to keep them with me. My comfort.',
#  'It was somewhat good until the end and the murder weapon made no sense to me. The turtle also had to be an acrobat to get to the different places.',
#  'There is a discover button that takes you to the shop. There, you can search for your favorite book. Unfortunately, after you find said book you can’t purchase it unless you go to a different browser or app and do so, there. I detest this.',
#  'This is wonderful! It has green background, witch I think is wonderful, and you can choose a profile picture, and you can rate books! This app is amazing. Number one choice for kindle fire users',
#  'I’ve been using an old Nook color reader which I loved but now I have a new friend. Great deals and prices.',
#  'Every time I try to install the kindle app it tells me I have a network error and that I need to connect to wifi.\n\nBut I AM  connected already so the error is  bogus.\n\nI use the kindle app extensively on my iPad and would like to have it on my phone as well.\n\nUPDATED\n\nAfter about the 10th try it finally let me sign in. I have changed the rating from a "1" to a "3".',
#  'Excellent book. Well developed characters. Very engrossing story.',
#  'Exhilarating read!',
#  '“Couldn’t put it down.”\n\n Seriously. Can’t wait to read another of his books.',
#  'Good story. I felt it was over to soon. Now I’ll have to see about the next book',
#  'I have been using the Kindle app on my iPhone 6s Plus for 2+ years and enjoy the interface. It’s a great way to carry around all of my books and even magazines and documents. \n\nI like all of the features such as changing fonts and turning the pages. Have had zero problems with the app. No crashing etc.',
#  'Not a one stop shop, you need to purchase a book separately then open the app to find it and read it.....or request a sample to be sent. Other apps are a one stop shop meaning you can buy the book through that app and read it right away instead of introducing more key strokes to your hands going from app to app. Also the password protection visual is impossible to read and took 1 attempts.',
#  'It’s a must have app',
#  'I have had this app for years and love it! Not only does kindle help you find free books there are also free book groups that add to these( like Pixelofink.com) Free books, plus the ability to red it on a font that’s easy for me to read, best app ever!',
#  'I can’t imagine anyone not using a Kindle if they have a sleeping, wake up early, spouse next to them. With my first Kindle I had a light on my ball cap 😂. \nSo for those of you, who haven’t experienced the black, sepia, green and white backlights, you need to check it out. \nI have no idea how many books I read a year because of Kindle.\nI was reading a Nora Roberts paperback I ordered by accident and found I couldn’t read as fast. So anyone who needs to get through a book quickly you might find that is helpful. \nI pack up my Kindle where ever I go. \nI read a book then immediately order another book with the purchase now button. Gotta love the convenience. \nI don’t know how I would have got through my illness without it. \nI escaped to every region in the US, Ireland, Scotland, Great Britain. I read the Outlander series before the TV series. I realized then I needed a never ending reading source. \nThank you Amazon 💜 Willa',
#  'Clumsy, non-intuitive, poor layout and design',
#  'Amazon really needs to allow users to set custom colors. Night mode still shines very blue light. Other reader apps can use red or dark orange text which is much easier on the eyes and doesn’t interfere with sleep. \n\nSimple feature that’s been missing for years.',
#  'I use this every day. It used to lose my highlights but it has been doing better for a while now. I’m very happy with this app. I use it for most of my reading.',
#  'This is literally the best app to read on. It has various features on it that can help you understand and expand your knowledge on that specific thing you are learning on and the better thing is that it is free and just a click away to being knowledgeable and intelligent. This app has taught me so much and it is amazing!!!!',
#  'Great new author I found on the Kindle app. 5 stars Jake',
#  'have always enjoyed the app until the latest update ... it doesn’t let you listen to music while reading ... completely unacceptable',
#  'I do not understand why I can not delete these books from this specific device! Always and forever a problem? Not happy!',
#  "I have spent two days trying to get free u limited to my child's iPad it says it sent it. It no where to find.\nThe stupid people on the phone couldn't even type the book title to find it. U need a masters to do this . Awful awful awful",
#  'It is so nice to be able to read ebooks with a Kindle. The app is so easy to use. Much better then my library’s reader app.',
#  'Reading on my iPhone is great, I love it.  What would make it a 5star rating is to be able to listen to the book.',
#  'I do love the kindle app but it drains my iPhone battery down to fast.',
#  'I would REALLY like to select from Google Fonts which ones I’d like to import. The fonts available in Kindle for iOS are pretty limiting. Google fonts should be easy to import directly from their website.',
#  'I don’t want to write a review',
#  'The only thing I don’t like about the Kindle app is I can’t order books for my Kindle app directly from the app.  Other than that, it is great!',
#  'I like reading books on my Kindle but it has been an app for a very long time and they really need to update it.  I would like to transfer books I have read into a separate category.  I would also like to alphabetize the books I have left to read or the books I have read.  My library has become very large and when you update the books do not say that you’ve read them but that they are “new”.  If not update this program someone make an app that can be used by kindle to do some of the things I’ve suggested',
#  'I like that I can download all my books here, very easy to use.  I didn’t give 5 star because I wish there was a way to hide or removed (not delete) already read books. When I got back a few months or even years to search through all my books, it takes me forever to find a book I haven’t read. A “already read l” section or option would be super helpful!  I have a ton of books and I’d like to not have to open/close multiple br I find what I want.',
#  "Do NOT get any EBOOK textbook via Amazon unless you like failing. Cannot take notes with apple pencil or scroll efficiently.\n\nIt's unacceptable that the Kindle is app is still garbage and doesn't allow you to write on the ebook or quickly swipe vertically through the pages. In a engineering class these are essential.... For $60 , I would expect to be able to fully engage with the text, but that is impossible with this book as I can't use my apple pencil because Kindle app is incompetent. Amazon needs to hire some of those comp sci interns to update this app and make it usable for students who need to write on the book in order to learn.\n\nThe built in note feature is garbage and a head ache to use, I recommend either buying the text copy or bootlegging a pdf. that actually lets you write on it. I'm against the bootlegging but the kindle's incompetence really leaves little choice. \nIt's a shame that software exists that I can put dog ears and a nose on my face instantly via a camera for FREE, but I can't write on a pdf. with an electronic pen for $60.00 = 8 hours minimum wage, which is what most buyers of this book are probably on. \nGet it together Amazon!",
#  'There used to be an option to hear how a word is supposed to be pronounced, but that option is gone. I deleted the app and re-installed it but that did not help. It would be really nice if that option were put back in place.',
#  'The app crashed twice today.  Time to look for another dictionary app!',
#  'It was interesting to see how many words have been subverted by leftist views. It is very distressing. This app, even if ad free is useless.',
#  'My speaker doesn’t work to pronounce the word correctly and I paid for grammar upgrade... this is a joke!',
#  'This app has too many ads. Ads are linked to fake scamming sites. I\'m disappointed a dictionary app supports scam sites...1 star.\n\nI have to pay to get "better definitions of words". No thanks....\n\nUpdate: pop up ads and video ads. Download a different dictionary app there’s plenty better ones out there.',
#  'When a person needs a definition it takes, maybe, 10 seconds to type in the word and read the definition or perhaps screenshot it.  HOWEVER, as soon as you get to your definition expect a LOUD ad to open up for 5 seconds.  NOT WORTH IT!',
#  'Due to the annoying video ads, I’ll find another option.',
#  'Used to be a great app now constant annoying pop ups',
#  'This app used to be great! It’s subpar at best now! The pronunciation function stopped working months ago. So annoying! I’m deleting this app, as of today!',
#  'This diectionary has been my go to for years and I have enjoyed the word of the day when I get bored now and then, but the blatent progressive/liberal bias that is seen is unrelenting. Any article, as well as many definitions, have an obvious tilt if not an outright allegiance to liberal ideology.',
#  'I used to be able to click the icon to play the audio for a word I was unsure of the pronunciation. Now that button doesn’t work. It’s been months!!!! Fix it!!! 😡',
#  'I downloaded this app over a year ago and purchased the maximum upgrade for $9.99. Well I just attempted to look up a medical term, and low and behold, I’m back to the basic edition. There was no indication when I bought the upgrade that it was only for a limited time. Had that ‘disclaimer’ been made upfront I would have NEVER wasted my money. And of course there’s no way to contact anyone about this. Until this issue gets resolved DO NOT USE THIS APP😡😡😡😡',
#  'The offline definitions are now locked behind a paywall.',
#  'The sound button never works. For a foreigner pronounciation is crucial.',
#  'I bought this app, paid money for a premium version. One day it starts displaying adds. Full screen and partial screen adds. Why did I pat money to upgrade? This is unacceptable.',
#  'Purchased the app to get rid of ads. But the app frequently crashes on me. If you click on a word within the definition to take you to another word, it won’t take you there. I have to close the app and reopen it because it won’t respond to anything. Also there needs to be a way to scroll through your favorites(and definitions of those words) instead of having to go back to the main page and click on favorites every time you want to look at another favorite word. I’ve started using dictionary on safari because it’s easier to deal with than the app.',
#  'For some reason the Dictionary app has stopped pronouncing the words! My volume key IS all the way up, and it has done absolutely nothing. I have had this app for years now, and all of a sudden it will not pronounce any of the words! Please, please, please fix this problem!',
#  'The words are no longer being pronounced by the speaker. Hope you can fix this problem. I have liked our app because it pronounces a word for me when I don’t know how to pronounce the word. And now it’s not working.',
#  'Even if you pay for these app they will still show you ads. I think this is a recent thing because I didn’t used to get them.',
#  'It has litterly all words from flimflam dinosaur and you can do the thesaurus if you want to.',
#  'I upgraded to get rid of the ads- still getting them. Even more lately. Used to be god app. Finding another dictionary app.,',
#  "Let's take a lesson on kap-i-tl-iz-uh m. I'm a guy, let's call me Brian or Daniel. I build a company with one objective on mind to sell it. Along the way, I don't mind taking your money. But when ask.com offers to buy the company, I jump up and down and say yes. Ask.com cares about the content, not the app. So features fall apart and I don't even have a support staff for it. I don't mind taking more money from unsuspecting saps who look at the long term ratings though. Now, you've paid, navigation doesn't work, and ask.com doesn't care about all the reviews that day the same thing.  Caveat emptor.",
#  'This is the best attitude, right? Earn more and more MONEY, while essential features in your app are not working... it doesn’t matter as long as the MONEY keeps pouring in from ads, right? \n\nThe app doesn’t pronounce any word... there is no sound at all... plus the ads are soooo annoying.... pop ups, videos, it takes 1-2 minutes to look up 1 ... ONE! .... word because of your ads. That’s what a responsible company does, right? \n\nThis company has become a money making machine by burning people’s nerves. Congrats! I regret I had paid for some extra features ...',
#  'It tends to freeze up during both online and offline modes. Sometimes the definitions don’t show and I’ll have to close the entire app out.',
#  'Great app but the ad’s are insane. The Two Dollar option to remove them is just as ridiculous.',
#  'Nunca te deja buscar palabras en español 🤬 parece que son prejuicios',
#  'There is no sound for the past month when I touch the button to pronounce the words. Can you check it out please?\nThank you.\n\nThere is no audio.  Help!\n\n03/28/19\n\nHear ye, hear ye....the volume is always at the maximum and the audio does not work.\nThis is my daily school work...help!\n\n04/04/19. Help!  There is no audio.',
#  'Love this app, except that the audio pronunciation feature is not working anymore. I have my volume set at max and don’t hear anything.',
#  'Good concept, but extra reading focuses too much on naughty subjects.  The gray type is much too small and too pale to read against the white background.',
#  'Audio doesn’t work & the ads tend to be overwhelming.',
#  'I don’t know if it’s a bug and getting ready for an upgrade but my app has been moving very slow. I can’t even search a word without closing and reopening my app again. Please fix soon.',
#  'Are you kidding? Deleting this app after I write this review. Title of the ad - why do we use euphemisms for certain body parts?',
#  'I had this app on my phone from the very start because it provided a feature no other dictionary had; namely the offline dictionary which you could use wherever and whenever. But for some reason it got deleted and after reinstalling it, I realized that now it was a paid feature and imagine how it felt like betrayal because before you could still pay for thesaurus and other things but have the offline dictionary along with ads, but now, it feels nothing but a sham. So sad to see so much potential go to waste.',
#  'I purchased several upgrades in 2014 and then my app wasn’t reflecting the upgrades. When I click restore purchases it states that no purchases have been made. I emailed customer service about it and screen shot my purchase history from iTunes. No response from customer service which was over a month ago.',
#  'I am upset that when a product call Kirin, the definition is Jilin. When you look at the cultural references it actually means 麒麟. This cross cultural stuff, makes everyone miserable. It was FORTUNATE that I know how to read Chinese. but isn’t the job of dictionary to reduce chances and making obvious?',
#  'You wont find it on my iPhone anymore',
#  'The ap is no longer any good. The company is no longer ethical. They’re living off the old approval ratings. You will regret this purchase.',
#  'The sound’s not working with volume up. I uninstalled reinstalled and it still doesn’t work.',
#  'The content is GOOD, HOWEVER. I use this app on an iPhone X and I cannot read a single word in the definition or synonym list without a damned MAGNIFYING GLASS.\n\nHonestly! My vision is 20/40. When will you get a clue about user interfaces??\nZooming by pinching text DOES NOT MAKE IT LARGE ENOUGH TO READ! But hey, it can sure make it microscopic.\n\nDuh? Ever think about testing it on something other than a big desktop?\n\nIn my phone’s Settings • General I have Larger Text turned ON. It says “Apps that support Dynamic Type will adjust to your preferred reading size below.” Guess what?\n\nObviously not only are your app developers oblivious (and they must have razor sharp vision—if you expect me to believe they can read text in this thing), even if I have the slider turned all the way to HUGE TEXT, only a slight  improvement. I paid for this?? Now looking for a real app in 2019!\n\nFinally, here’s the other thing inexperienced UI developers do: they try to go for a “clean look” by only using sans serif fonts. Big mistake: serif fonts are easier to read. Also the weight of the font is very thin—harder to read!\n\nNow who wants to hate on me for pointing out the failed state of an app designed for people who READ and want to improve or refresh their knowledge of words? Like we users should actually be able to READ IT? Obviously even as a paid user, you don’t care if it’s worth anything. I’ll find one that’s usable and if you don’t fix this one soon, I’m going to delete it and ask for a REFUND. Good luck.\n\nSo if you thought all of the above was an annoying review, I tried to follow it up by using your “We’d love to hear from you” thing that like this app clearly has no connection to the idea of providing anything of value to users.\n\nSo now the App Store readers get to read those add’l remarks, too:\n\nGreat, this PROVES your disdain for being responsive to users. I had to pick up my magnifying glass yet again just to fill out your stupid feedback form, and try to read its tiny gray sans-serif font.\n\nI just put in a scathing review of your app. No doubt someone there who is totally wrong will claim that it’s not you, it’s me and my critical review was not justified. If there’s a chance that you ever do any testing (or there is a scientific basis for any aspect of the app developers’ UI parameters and requirements, why don’t you TEST IT?\n\nMaking a dictionary app that is unreadable? That’s so ridiculous it writes its own jokes. You finish the analogy. I’m going to do and use something else.\n\nI just want you to know that I don’t make idle threats. If you cannot make that app READABLE—I need a refund. Heck, you should PAY ME ANYWAY for pointing this out.\n\nNot your enemy,\n\n{Me}\n\nPS: Obliviousness to users is typified by the large button below this text input box. {Which of COURSE DOES NOT WORK—like your dev team. Hence I went to the trouble of pasting it here and dropping this review from 2 to 1 star.}\n\nOn my iPhone the blue button is about 8x27 mm but the antiquated/offensive word Submit is only about 3x11 mm. Eventually we all must submit to our creator but in this world producers must “submit” to consumers, not the other way around!\n\nInstead of Submit, save energy and use Send. It’s also not suggestive that you lord over me, which you obviously don’t.',
# ...
#  'Enough said.',
#  'I am going to have t-Rex as a pet I,ll give him food he eats panda,s  dinosaurs and dragons,',
#  'My 5 year old loves this app. Excellent!! Read to me or even allows the child to flip the pages reader or I can read the story to him at our leisure. I only wish they had more Smithsonian topics to buy. ie Flight or Natural History This is amazing.',
#  'My son has read this book about 10 times already.  The graphics are beautifully done.  If he likes it, so do I.',
#  "And this isnt one my son (4yrs) favorites. He really likes to poke around and see the different words for the objects on the screen. There very few selectable object compared to other of there books lines and it doesn't say the words for the few object anyways. It pretty book, just not on par with the Dr Seuss or Little Critter books.",
#  'Great book. My son absolutely lived it!',
#  'Download and have fun!!!',
#  'Buy it if you have a dinosaur lover!!!',
#  'He loves it!!',
#  "My 5 yr old nephew is going to love this app--the T-Rex is his favorite dinosaur.  Don't hesitate to buy if you know a dinosaur lover.  As usual, Smithsonian does a great job.",
#  'My 7 year old loved it but we were both surprised at how brief it was.',
#  "And the guy says tynrranasaurus Rex sooo many time.  And the artwork isn't really that good.   Really like the dr Seuss books.  This one not so much.",
#  "For the price it's a good multimedia book experience. No animation--just pan and zoom--but good illustrations and narrative without being over sensational. My 2.5 year old loves it and isn't scared which is a good sign.",
#  'The graphics are wonderful but the length of the book was too short. My kids were like, is that it?',
#  'The music and sound effects really bring this story to life. My 9 year old pretended that he was too cool to enjoy it, but I caught him reading the story over and over!  Well done',
#  'This app is a must have! My husband drove for 8 hours and I run out of things to do to entertain my toddler. I was lucky to find this app and immediately got. It helped us to finalize a  successful and long road trip!',
#  'My son loved it!',
#  'Another awesome interactive book from OM.  My 3-year-old son loves this book - I enjoy it, too.  Great narration and captivating story.',
#  'My grandson just loves dinosaurs, and this story idea is fantastic!  Great read to me or read on his own app.  Since he is prekindergarten, we really like the read to me feature.',
#  'my 3 yr old loves it!!!!!!',
#  "My 4 yr old & I were both caught up in the drama. He's watched it 3 times already. Lol. Fun & Educational.",
#  'Awesome app',
#  "I was excited to find this because I wanted to do some things with US paper money and was having problems with the shape.  Unfortunately, after trying to figure out what I was doing wrong, I noticed the folds weren't possible.  It would be nice if it listed the currency it works with.",
#  "It just doesn't work with US dollars. Pretty cool though",
#  'Great app! Much better than the other money origami app in the App Store. Was just looking for basic, app-sized instructions for folding money, and this is it!',
#  "Why are the instructions using stupid drawings I thought this would be like 3D origami but better but it's kinda \ue05a\n\nI'll rate 5 stars when I see actual money being demonstrated in the pictures. Till then \ue335",
#  'This should be the standard issue app when you get a ccw ,, always updated ,,, when in doubt look it up ....',
#  'I travel all over the United States for work. This app is incredible. Very up to date, and very user friendly.\nI would, and have, recommend it to anyone looking to travel that carries their firearms with them.',
#  'Not many times will you open the app and not have law updated to load. Great piece of mind as you’re traveling. Very easy to keep up with rules and regulations. Clear and concise navigation through the app. Highly recommend this app for anyone with a CCW',
#  'Thank you!',
#  'Very good and handy reference!',
#  'It’s the best to be informed on rules of each state and be aware of my legal issues on every state.',
#  'This is the best CCW resource available.\nI have been using this CCW application  for ten or more years and never found it lacking.',
#  'Always helpful we even use it when we reach our CCW class so students know where to stay legal',
#  'Constant updates so the info is up to date',
#  'One of the few keepers I have on my phone.  Yeah, it’s now subscription based but keeping fifty states laws current is not a task I would want to do, I can handle a buck a year subscription.',
#  'This app never ceases to satisfy my needs for up to date laws and regulations. Constantly evolving and easy to navigate.',
#  'Fantastic app that gives me an update of the states I may be traveling through and visiting!',
#  'Only CCW app that shows ALL information required state by state. Updates with all new information. BEST!!',
#  'Great app keeps inform keeps you from breaking the law in some states .',
#  'I liked this app but I guess now they want me to pay a subscription. What ever happened to pay once and enjoy?',
#  'No doubts that this is the best app for all laws by state for a ccw permit info.',
#  'I have purchased other ccw apps but they are no way as informative as this one.\n\nAlso they update regularly.',
#  'The CCW app is a must have when you have a CCL especially when you travel. When I plan a trip the fist thing I do is map out my route and go through the app so I know exactly what the laws are so I’m not breaking any laws. Love this app and definitely recommend it!',
#  'This is a great app and has all the information I need when planning a trip. From the laws governing transportation of my CCW to where I am allowed to carry. The ease of operation and abundance of information is awesome. I would suggest this app to other CCW carriers.',
#  'I travel with my firearms often. This app keeps me informed and up to date in real time😎👍',
#  'Great sight. Very informative.  Can’t wait to be informed when Maryland changes their laws.  Meanwhile, one can only hope!',
#  'Very useful.',
#  'Best CCW information app I’ve seen.\nEasy to use, and updated at least monthly.\nI don’t leave home without it.',
#  'Very handy app to have while carrying cross country. I love all the updates to keep me current on local laws.',
#  'Great information!\nVery simple to understand.',
#  'EXTREMELY HELPFUL COVERS A LOT OF DETAIL',
#  'I’ve been a SC CWP instructor for many years and love this app. I direct ALL of my students to this and tell them that this is one of the best companions since the pistol. \nThank you for putting together such detailed information into one place, and the fact that I can take it with me anywhere is so convenient!!!',
#  'This is an amazing CCW app. A must have if  you travel. It provides comprehensive, easy to read information on all states \n\nI also have Legal Heat, and this CCW app is much better \n\nSupport is amazing in the rare event it is needed. My State definition files got wonky and within the same day, with only 4 emails passed, the problem was solved\n\nI highly recommend this app',
#  'This is the most helpful and accurate app I have ever downloaded. It give you all the information you need when traveling with a weapon. I would recommend anyone to get this app.',
#  'Great app for quick information for all',
#  'This has so much information in it about gun laws. It is a must have for anyone who travels with a firearm. All the states are covered as well as federal and most tribal land. Well worth the money. Could save you lots of money and headaches should you get caught caring when or where you are not allowed',
#  'If you travel outside your own state, whether for business or leisure, this app will be your best friend. Will keep you out of trouble.',
#  'Excellent source of important information that you need if you travel.',
#  'Covering ALL STATES in every area needed to maintain legality by State laws. \nBecause All States do no Adhere to the CONSTITUTION of  the UNITED STATES of AMERICA. \nGreat Work..\n\nBill',
#  'I was looking for an app that can be used across multiple iOS devices without having to re-key information. The app meets that criteria but has some issues that I hope will be solved in future releases because so far I like the app even with the issues I found. I prefer to do the data entry on my iPad and track by training sessions on my iPhone.\n\nThe following are my initial observations after using the app for about an hour. I transferred all the information on my firearms, permits and some of my training sessions. \n\nThere are two resident permits for Illinois but there is only one entry so I had to use the non-resident for the second. \n\nIt does not have a complete inventory of firearms and ammunition. How could you not have an entry for a Ruger 10/22? It’s very handgun oriented. I am also an avid Olympic Pellet shooter which is ignored. I wish they would allow you the freedom to enter what is not in the inventory rather than just “OTHER “.\n\nI attempted to add photographs of my firearms several times and the app just terminated. When I tried to delete a firearm, it didn’t happen immediately and I had to log out and log back in to delete the firearm. I used the note section to keep track of purchase price. I wish It had the ability to add photos to your training sessions.',
#  'Great app very informative very useful from state to state',
#  'This last update makes you repay for the app or lose access to all the information stored on what was paid for previously, apparently greed is good and this company is full of it. The products maker have taken the time to solve my problems thank you.',
#  'Keeps you well informed!',
#  'Very helpful AND current items , appreciate updates that otherwise might never be aware of',
#  'This is the best CC app I’ve found. Easy to use and very clearly displayed. Every time I open it, it does an update.',
#  'They update regularly. My go to app for travel with a gun.',
#  'Love it!',
#  'Has all the information so I don’t get in trouble with the law while traveling.',
#  'Solid app that all CCW individuals should holster in their phones. UI could use some updating for simpler navigation and some eye candy. I’d like a section that simplified some of the laws in addition to just the current style of linking to the law directly.',
#  'Please make your App less Confusing to navigate on \n\n     Thank You',
#  'App developer seems interested in keeping it up to date as possible given the constantly evolving rule changes.  I notified them of a broken link to external website and they had it fixed the next day.  Great app, simple to use.',
#  'Thank you for fixing it!',
#  'I have been using this for well over a year now. One of the best purchases I’ve made. I also got the “Posted” app too. Both of them are excellent!!!!',
#  'I am a veteran and commercial truck driver..I live by this app. to keep me legal in all states I travel..thank you...',
#  'Well done app. Great way to start off the day. 🙏🏻',
#  'I have had this app and audio for quite a while and I have found it it to be WONDERFUL! I have shared it with many of my family and friends! The audio is excellent!!! Well worth the purchase!!!!!',
#  'More convenient and less expensive than my physical copy!',
#  'If you want to know the true and gentle voice of Jesus you must read this book or have this app. We often fear the mighty power of God so much that we fear getting close to His son. Before you decide how you feel about God... Learn how God feels about you. Beautiful Kind amazing Jesus.',
#  'I’ve worn out the hardback book, so now I use the app version when I travel. Wonderful. Would love to be able to highlight text.',
#  "I love being able to read daily wherever I an and whenever I need a reminder from Him that he's always with me. I'd love a similar App for Jesus Always.",
#  "When I open the app it is just a white screen. I've always loved this app but now it's useless. Feel like my money was wasted. Please help.",
#  'Missing a highlighter',
#  'Jesus Calling is one of the absolute best devotionals available. This devo continues to improve my life daily! I have the book in several forms but love the app for travel.',
#  'I love my Jesus Calling app and use it almost everyday. It shows there is an audio version, but I cannot find it anywhere in the App Store. Can you please help me? I have a friend who can’t see well due to cataracts and I would like to gift one to her. \nThanks',
#  'Please make a version that fits the iPhone X resolution. It’s cut off at the top and bottom.',
#  'Absolutely inspiring devotional !  \nI read it everyday day ( mostly ) year after year and each time, I get different inspirations from the Word and her daily devotionals for the different situations I am in. Absolutely amazing to me ! \nI love the note taking feature !\nI also send inspiration notes to my friends.',
#  'I use this almost every day and pleased to have it.  I like to copy a portion that means something special to me that day and paste it in notes.  Then I like zoo go back and copy the. Erase that backs it up and paste T underneath.  However, often the first item copied has disappeared.  .?? What’s the point of copying and pasting if it won’t save permanently??',
#  'I use this app during my breaks at work and love it; the only thing I wish would to turn your other books in apps also!!!',
#  'I have two of the books but they never seem to be where I need them. This app makes the devotionals available whenever and wherever I need them!',
#  'I have tried to gift this app three times today.  It says it has been “scheduled”... whatever that means... but no one has received the app..called shaper Collins and was disconnected three times...',
#  'This book is so wonderful it’s like Jesus is talking directly to you! 🤗😍',
#  'Please bring back JCK: it is my family’s favorite app! Thank you bless you',
#  'Since the most recent update occurred, I can no longer copy, post on image, and share this devotional on social media. Please fix soon!',
#  'This is a great app! I always enjoy using it!',
#  'I have witnessed the effects of Jesus On several of my friends after they added this daily read. Truly amazing!!!',
#  'If you’re charging for an app, you keep it updated. The fact that it looks terrible on the (Not-so-new) iPhone X is frustrating. \n\nI’ll have five stars ready for you when it seems you’re supporting the app you are charging good money for.',
#  'I love waking up and Jesus is watching!  I have highly recommended this app.',
#  'When I hit “share text”, then sent it to myself, it only shows me the option to purchase the Jesus Calling app.  How is that sharing the text from a particular day’s devotion???',
#  'Love the word this app send me throughout the year. Awesome thing I need to hear from time to time',
#  'I have the various books written by Sarah Young, however the app reminds me, to read the subtle ways of the gospel for that particular day. I have had this app since it first was developed. Love it and use it everyday. Thank you',
#  'For the most part I enjoy the devotional... I find it disturbing when the scriptures do not properly capitalize “Him”, “He”, etc. (when referring to God).\n\nAlso, it would be nice if the app filled my screen (I have an iPhone X). I feel like I’m reading an outdated app.',
#  'Would be great to be able highlight or underline text',
#  'This application worked great until the most recent update. Now when it starts up all that happens is a white screen.  Rebooting the phone has not helped. Uninstalling and reinstalling has not helped.  Please fix this app so I can be wonderful and useful again.',
#  'After the up date this app it will not open on my phone. It goes to a blank white screen? Can you suggest a solution? I have had the app for more than a yr. & loved it. I would love to have access to it again.',
#  'I LOVE the Jesus Calling book. The app has completely stopped working. I am only getting a white screen when I try opening it. Super sad.',
#  ...]

# %% [markdown]
# # simple sentiment analysis

# %%
apple_bkref_rev_str = ''.join(apple_bkref_rev)##use 空格 来 分隔每个element
apple_business_rev_str = ''.join(apple_business_rev)
apple_edu_rev_str = ''.join(apple_edu_rev)
apple_ent_rev_str = ''.join(apple_ent_rev)
apple_fin_rev_str = ''.join(apple_fin_rev)
apple_fodr_rev_str = ''.join(apple_fodr_rev)
apple_healfit_rev_str = ''.join(apple_healfit_rev)
apple_life_rev_str = ''.join(apple_life_rev)
apple_med_rev_str = ''.join(apple_med_rev)
apple_nav_revs_str = ''.join(apple_nav_rev)
apple_news_rev_str = ''.join(apple_news_rev)
apple_phovid_rev_str = ''.join(apple_phovid_rev)
apple_prod_rev_str = ''.join(apple_prod_rev)
apple_shop_rev_str = ''.join(apple_shop_rev)
apple_social_rev_str = ''.join(apple_social_rev)
apple_sports_rev_str = ''.join(apple_sports_rev)
apple_travel_rev_str = ''.join(apple_travel_rev)
apple_util_rev_str = ''.join(apple_util_rev)
apple_weather_rev_str = ''.join(apple_weather_rev)
#not_included = ''.join(bkref_rev)

# %%
do_pos_neg_sentiment_analysis([('apple_bkref_rev',apple_bkref_rev_str),('apple_business_rev', apple_business_rev_str),('apple_edu_rev',apple_edu_rev_str),
                              ("apple_ent_rev",apple_ent_rev_str),("apple_fin_rev",apple_fin_rev_str),("apple_fodr_rev",apple_fodr_rev_str),
                               ('apple_healfit_rev',apple_healfit_rev_str),("apple_life_rev",apple_life_rev_str),
                               ("apple_med_rev",apple_med_rev_str),("apple_nav_revs",apple_nav_revs_str),("apple_news_rev",apple_news_rev_str),
                               ("apple_phovid_rev",apple_phovid_rev_str),("apple_prod_rev",apple_prod_rev_str),
                               ("apple_shop_rev",apple_shop_rev_str),("apple_social_rev",apple_social_rev_str),
                               ("apple_sports_rev",apple_sports_rev_str),("apple_travel_rev",apple_travel_rev_str),
                               ("apple_util_rev",apple_util_rev_str ),("apple_weather_rev",apple_weather_rev_str)
                              ])
# Out:
# [('apple_bkref_rev', 0.046843073150796895, 0.014941765427053534),
#  ('apple_business_rev', 0.04036139607799995, 0.017313457465826892),
#  ('apple_edu_rev', 0.045445660318620976, 0.01692108320995609),
#  ('apple_ent_rev', 0.04042125792296441, 0.01889289777344385),
#  ('apple_fin_rev', 0.0357064877218009, 0.017583953187091515),
#  ('apple_fodr_rev', 0.04039607563649598, 0.017362427403824283),
#  ('apple_healfit_rev', 0.04327058256456947, 0.0179348480994015),
#  ('apple_life_rev', 0.04153694965604675, 0.017749037906123644),
#  ('apple_med_rev', 0.03953771289537713, 0.01629112451073733),
#  ('apple_nav_revs', 0.0354117450545255, 0.015963920108812372),
#  ('apple_news_rev', 0.0342001001867116, 0.022132155380481806),
#  ('apple_phovid_rev', 0.04574055595802749, 0.01682408635073379),
#  ('apple_prod_rev', 0.041403339590042075, 0.017160028241290835),
#  ('apple_shop_rev', 0.03593678181239614, 0.0182512463317187),
#  ('apple_social_rev', 0.033298546557837046, 0.021570104567664887),
#  ('apple_sports_rev', 0.03676233739417716, 0.020334503406979145),
#  ('apple_travel_rev', 0.03630030341743852, 0.017137096774193547),
#  ('apple_util_rev', 0.04118342752698426, 0.018567602058703916),
#  ('apple_weather_rev', 0.04240215743960061, 0.017685209949184273)]

# %% [markdown]
# <h2>Simple sentiment analysis using NRC data</h2>

# %%
comparative_emotion_analyzer([('apple_bkref_rev',apple_bkref_rev_str),('apple_business_rev', apple_business_rev_str),('apple_edu_rev',apple_edu_rev_str),
                              ("apple_ent_rev",apple_ent_rev_str),("apple_fin_rev",apple_fin_rev_str),("apple_fodr_rev",apple_fodr_rev_str),
                               ('apple_healfit_rev',apple_healfit_rev_str),("apple_life_rev",apple_life_rev_str),
                               ("apple_med_rev",apple_med_rev_str),("apple_nav_revs",apple_nav_revs_str),("apple_news_rev",apple_news_rev_str),
                               ("apple_phovid_rev",apple_phovid_rev_str),("apple_prod_rev",apple_prod_rev_str),
                               ("apple_shop_rev",apple_shop_rev_str),("apple_social_rev",apple_social_rev_str),
                               ("apple_sports_rev",apple_sports_rev_str),("apple_travel_rev",apple_travel_rev_str),
                               ("apple_util_rev",apple_util_rev_str ),("apple_weather_rev",apple_weather_rev_str)
                              ])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-25c64e7a77c1> in <module>
# ----> 1 comparative_emotion_analyzer([('apple_bkref_rev',apple_bkref_rev_str),('apple_business_rev', apple_business_rev_str),('apple_edu_rev',apple_edu_rev_str),
#       2                               ("apple_ent_rev",apple_ent_rev_str),("apple_fin_rev",apple_fin_rev_str),("apple_fodr_rev",apple_fodr_rev_str),
#       3                                ('apple_healfit_rev',apple_healfit_rev_str),("apple_life_rev",apple_life_rev_str),
#       4                                ("apple_med_rev",apple_med_rev_str),("apple_nav_revs",apple_nav_revs_str),("apple_news_rev",apple_news_rev_str),
#       5                                ("apple_phovid_rev",apple_phovid_rev_str),("apple_prod_rev",apple_prod_rev_str),
#
# NameError: name 'comparative_emotion_analyzer' is not defined
